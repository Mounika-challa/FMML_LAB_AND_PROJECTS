# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounika-challa/FMML_LAB_AND_PROJECTS/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-06 14:42:26--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   262MB/s    in 0.3s
#
# 2024-04-06 14:42:27 (262 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26274  1609.06341v1  Problem of impulse noise reduction is a very w...    cs
# 5945    1305.4324v1  We study online learning under logarithmic los...    cs
# 7407   1712.05689v1  Recently, deep neural networks (DNNs) have bee...  stat
# 12429  1802.00130v1  Deep learning involves a difficult non-convex ...  stat
# 37934   1204.0585v4  This paper studies iteration convergence of Kr...  stat
# ...             ...                                                ...   ...
# 21542   1002.3684v1  Independent component analysis (ICA) aims at d...  stat
# 10741   1401.0118v1  Variational inference has become a widely used...  stat
# 16964  1707.06957v1  Pre-trained word embeddings improve the perfor...    cs
# 22832  1708.01529v1  We introduce a new algorithm for approximate i...  stat
# 37317  1703.06109v1  The principle of the common cause claims that ...  stat
#
#                                                    title  year  \
# 26274  Markov Random Field Model-Based Salt and Peppe...  2016
# 5945   Horizon-Independent Optimal Prediction with Lo...  2013
# 7407   BT-Nets: Simplifying Deep Neural Networks via ...  2017
# 12429  Distributed Newton Methods for Deep Neural Net...  2018
# 37934  Convergence Properties of Kronecker Graphical ...  2012
# ...                                                  ...   ...
# 21542  Robust Independent Component Analysis by Itera...  2010
# 10741                    Black Box Variational Inference  2013
# 16964  Reconstruction of Word Embeddings from Sub-Wor...  2017
# 22832  Learning Model Reparametrizations: Implicit Va...  2017
# 37317    Generalised Reichenbachian Common Cause Systems  2017
#
#                                                 keywords
# 26274  [reduction, processing, community, different, ...
# 5945   [logarithmic, parametric, prediction, sequenti...
# 7407   [classification, applications, especially, cla...
# 12429  [difficult, optimization, structure, complicat...
# 37934  [iteration, convergence, kronecker, graphical,...
# ...                                                  ...
# 21542  [independent, component, decomposing, statisti...
# 10741  [variational, inference, approximate, posterio...
# 16964  [embeddings, performance, increasing, operatin...
# 22832  [introduce, algorithm, approximate, inference,...
# 37317  [principle, improbable, coincidence, generally...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26274    [reduction, processing, community, different, ...
# 5945     [logarithmic, parametric, prediction, sequenti...
# 7407     [classification, applications, especially, cla...
# 12429    [difficult, optimization, structure, complicat...
# 37934    [iteration, convergence, kronecker, graphical,...
#                                ...
# 7140     [algorithm, alternating, direction, multiplier...
# 2620     [visualizations, interpretable, preferences, s...
# 7444     [documented, performance, nonlinear, preselect...
# 6323     [probabilistic, factorization, effective, algo...
# 12197    [decreasing, attention, underscore, analytics,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8899 words.
# Out of those 4591 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="50ca0f1c-5d11-47f5-a8a5-4962ae3be452" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50ca0f1c-5d11-47f5-a8a5-4962ae3be452")) {                    Plotly.newPlot(                        "50ca0f1c-5d11-47f5-a8a5-4962ae3be452",                        [{"x":["inpainting","similarity","approaches","considered","formulation","investigations","minimization","comparisons","processing","techniques","computational","expansion","superiority","different","reduction","investigated","community","optimization","structural","functional","smoothness","logarithmic","prediction","sequential","exchangeability","dimensional","independent","strategies","exchangeable","calculated","distributions","exponential","parametric","normalized","likelihood","applications","situations","connected","deployment","researchers","compressed","decomposition","benchmark","operators","extensive","experiments","requiring","redundancy","compression","representation","computing","specifically","resources","performance","simplifying","classification","parameters","promising","preserving","demonstrate","significantly","especially","complicated","diagonalization","synchronization","consumption","bottleneck","incorporated","calculation","stochastic","distributed","environments","particular","subsampled","difficult","direction","approximate","partitions","thoroughly","terminate","structure","implementation","communication","explicitly","expensive","effective","iteration","estimator","multivariate","distribution","algorithms","asymptotic","pointwise","establish","algorithm","regularized","covariance","penalized","originally","properties","variables","kronecker","convergence","presented","introduced","estimation","implements","imputation","penalties","application","generalizes","covariances","graphical","estimating","transposable","selection","simulations","probability","framework","combination","adaptation","generalised","adversarial","approximates","demonstrates","theoretical","conditional","leverages","accurately","architecture","unlabelled","viability","transductive","available","potential","procedure","probabilistic","generating","distinguishing","extremely","inception","resolutions","baselines","specifies","recognizable","discriminator","databases","determines","equilibrium","appealing","achieving","collapsing","effectively","intuition","efficiently","utilizing","synthetic","classifier","capturing","mechanism","generative","generator","delivering","parameter","generated","generators","overcoming","empirical","divergence","diversity","repulsion","continuous","applicable","efficient","eigendecomposition","processes","determinantal","progression","perception","objective","vanishing","practical","statistical","modelling","smoothing","counterpart","furthermore","incorporating","explanations","providing","densities","pathologies","estimates","gradients","effectiveness","distinction","simulated","volumetric","tractography","transform"],"y":[10,133,427,137,78,11,65,46,277,362,294,19,42,755,89,52,72,331,67,36,18,24,208,78,3,182,130,107,3,25,114,46,42,32,64,432,47,68,16,62,24,63,205,47,181,576,38,16,40,332,135,168,67,893,3,473,243,103,43,560,263,121,37,1,6,20,15,19,20,122,111,87,272,1,120,55,95,9,18,1,343,123,62,66,68,238,43,28,22,206,606,13,3,40,851,50,23,5,14,200,112,1,111,162,143,209,15,4,3,249,26,1,58,58,0,160,33,167,538,123,73,8,108,8,46,160,95,36,57,230,3,1,4,288,137,110,169,98,13,49,15,16,45,10,2,13,68,19,19,18,86,5,107,19,156,37,130,149,42,102,114,36,6,131,162,9,11,150,25,48,0,111,48,382,0,109,4,8,37,174,16,135,167,50,15,20,171,54,14,80,8,2,84,40,199,4,64,9,0,61],"type":"bar"},{"x":["inpainting","similarity","approaches","considered","formulation","investigations" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4591,), (4591, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8116666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>DeepSaliency</span> <span style=''>Multi</span> <span style=''>Task</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>Model</span> <span style=''>for</span> <span style=''>Salient</span> <span style=''>Object</span> <span style='background-color:rgba(0, 255, 0, 0.5184381778741864);'>Detection</span> <br/><br/><span style=''>A</span> <span style=''>key</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>salient</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.5184381778741864);'>detection</span> <span style=''>is</span> <span style=''>how</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.31288343558282206);'>effectively</span> <span style=''>model</span> <span style=''>the</span> <span style=''>semantic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>salient</span> <span style=''>objects</span> <span style=''>in</span> <span style=''>a</span> <span style=''>data</span> <span style=''>driven</span> <span style=''>manner</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>deep</span> <span style=''>saliency</span> <span style=''>model</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.5661605206073752);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>(FCNN)</span> <span style=''>with</span> <span style=''>global</span> <span style=''>input</span> <span style=''>(whole</span> <span style=''>raw</span> <span style=''>images)</span> <span style=''>and</span> <span style=''>global</span> <span style=''>output</span> <span style=''>(whole</span> <span style=''>saliency</span> <span style=''>maps)</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>saliency</span> <span style=''>model</span> <span style=''>takes</span> <span style=''>a</span> <span style=''>data</span> <span style=''>driven</span> <span style=''>strategy</span> <span style=''>for</span> <span style=''>encoding</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>saliency</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>and</span> <span style=''>then</span> <span style=''>sets</span> <span style=''>up</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>learning</span> <span style=''>scheme</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>exploring</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>saliency</span> <span style='background-color:rgba(0, 255, 0, 0.5184381778741864);'>detection</span> <span style=''>and</span> <span style=''>semantic</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6785714285714286);'>segmentation</span> <span style=''>Through</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collaborative</span> <span style=''>feature</span> <span style=''>learning</span> <span style=''>from</span> <span style=''>such</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style=''>tasks</span> <span style=''>the</span> <span style=''>shared</span> <span style=''>fully</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Randomized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Causation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Coefficient</span> <br/><br/><span style=''>We</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interested</span> <span style=''>in</span> <span style=''>learning</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>pairs</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>purely</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>data</span> <span style=''>To</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>address</span> <span style=''>this</span> <span style=''>task</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanisms</span> <span style=''>mapping</span> <span style=''>causes</span> <span style=''>to</span> <span style=''>effects</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invertibility</span> <span style=''>or</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>additive</span> <span style=''>noise</span> <span style=''>which</span> <span style=''>only</span> <span style=''>hold</span> <span style=''>in</span> <span style=''>limited</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situations</span> <span style=''>On</span> <span style=''>the</span> <span style=''>contrary</span> <span style=''>this</span> <span style=''>short</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>how</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>directly</span> <span style=''>from</span> <span style=''>data</span> <span style=''>and</span> <span style=''>without</span> <span style=''>the</span> <span style=''>need</span> <span style=''>of</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>pose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>causality</span> <span style=''>as</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>mean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>inputs</span> <span style=''>are</span> <span style=''>samples</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>on</span> <span style=''>pairs</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>and</span> <span style=''>labels</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Perceptron</span> <span style=''>Mistake</span> <span style=''>Bounds</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>brief</span> <span style=''>survey</span> <span style=''>of</span> <span style=''>existing</span> <span style=''>mistake</span> <span style=''>bounds</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>novel</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Perceptron</span> <span style=''>or</span> <span style=''>the</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Perceptron</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>Our</span> <span style=''>novel</span> <span style=''>bounds</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalize</span> <span style=''>beyond</span> <span style=''>standard</span> <span style=''>margin</span> <span style=''>loss</span> <span style=''>type</span> <span style=''>bounds</span> <span style=''>allow</span> <span style=''>for</span> <span style=''>any</span> <span style=''>convex</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.47368421052631576);'>Lipschitz</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>and</span> <span style=''>admit</span> <span style=''>a</span> <span style=''>very</span> <span style=''>simple</span> <span style=''>proof</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>In</span> <span style=''>Defense</span> <span style=''>of</span> <span style=''>MinHash</span> <span style=''>Over</span> <span style=''>SimHash</span> <br/><br/><span style=''>MinHash</span> <span style=''>and</span> <span style=''>SimHash</span> <span style=''>are</span> <span style=''>the</span> <span style=''>two</span> <span style=''>widely</span> <span style=''>adopted</span> <span style=''>Locality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sensitive</span> <span style=''>Hashing</span> <span style=''>(LSH)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>Deciding</span> <span style=''>which</span> <span style=''>LSH</span> <span style=''>to</span> <span style=''>use</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>problem</span> <span style=''>at</span> <span style=''>hand</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>question</span> <span style=''>which</span> <span style=''>has</span> <span style=''>no</span> <span style=''>clear</span> <span style=''>answer</span> <span style=''>in</span> <span style=''>the</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>In</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>answer</span> <span style=''>(validated</span> <span style=''>by</span> <span style=''>experiments)</span> <span style=''>that</span> <span style=''>MinHash</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>virtually</span> <span style=''>always</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>SimHash</span> <span style=''>when</span> <span style=''>the</span> <span style=''>data</span> <span style=''>are</span> <span style=''>binary</span> <span style=''>as</span> <span style=''>common</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>such</span> <span style=''>as</span> <span style=''>search</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>MinHash</span> <span style=''>is</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resemblance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>(mathcalR)</span> <span style=''>while</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>SimHash</span> <span style=''>is</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>cosine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>(mathcalS)</span> <span style=''>To</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>common</span> <span style=''>basis</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>we</span> <span style=''>evaluate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retrieval</span> <span style=''>results</span> <span style=''>in</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09732620320855614)
# 	architecture (0.08199643493761141)
# 	challenging (0.10053475935828877)
# 	segmentation (0.06702317290552584)
# 	information (0.24242424242424243)
# 	experimental (0.14188948306595364)
# 	detection (0.12477718360071301)
# 	convolutional (0.128698752228164)
# 	different (0.26916221033868093)
# 	recognition (0.13297682709447414)
#
# Some Statistics words are:
# 	algorithm (0.3879699248120301)
# 	variational (0.1012531328320802)
# 	stochastic (0.13283208020050125)
# 	statistical (0.1548872180451128)
# 	variables (0.1418546365914787)
# 	estimation (0.17844611528822055)
# 	dimensional (0.17944862155388472)
# 	distribution (0.1899749373433584)
# 	inference (0.19799498746867167)
# 	regression (0.1774436090225564)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="82b964a4-329c-4c67-9805-84265afd9915" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82b964a4-329c-4c67-9805-84265afd9915")) {                    Plotly.newPlot(                        "82b964a4-329c-4c67-9805-84265afd9915",                        [{"x":["inpainting","similarity","approaches","considered","formulation","investigations","minimization","comparisons","processing","techniques","computational","expansion","superiority","different","reduction","investigated","community","optimization","structural","functional","smoothness","logarithmic","prediction","sequential","exchangeability","dimensional","independent","strategies","exchangeable","calculated","distributions","exponential","parametric","normalized","likelihood","applications","situations","connected","deployment","researchers","compressed","decomposition","benchmark","operators","extensive","experiments","requiring","redundancy","compression","representation","computing","specifically","resources","performance","simplifying","classification","parameters","promising","preserving","demonstrate","significantly","especially","complicated","diagonalization","synchronization","consumption","bottleneck","incorporated","calculation","stochastic","distributed","environments","particular","subsampled","difficult","direction","approximate","partitions","thoroughly","terminate","structure","implementation","communication","explicitly","expensive","effective","iteration","estimator","multivariate","distribution","algorithms","asymptotic","pointwise","establish","algorithm","regularized","covariance","penalized","originally","properties","variables","kronecker","convergence","presented","introduced","estimation","implements","imputation","penalties","application","generalizes","covariances","graphical","estimating","transposable","selection","simulations","probability","framework","combination","adaptation","generalised","adversarial","approximates","demonstrates","theoretical","conditional","leverages","accurately","architecture","unlabelled","viability","transductive","available","potential","procedure","probabilistic","generating","distinguishing","extremely","inception","resolutions","baselines","specifies","recognizable","discriminator","databases","determines","equilibrium","appealing","achieving","collapsing","effectively","intuition","efficiently","utilizing","synthetic","classifier","capturing","mechanism","generative","generator","delivering","parameter","generated","generators","overcoming","empirical","divergence","diversity","repulsion","continuous","applicable","efficient","eigendecomposition","processes","determinantal","progression","perception","objective","vanishing","practical","statistical","modelling","smoothing","counterpart","furthermore","incorporating","explanations","providing","densities","pathologies","estimates","gradients","effectiveness","distinction","simulated","volumetric","tractography","transform","reformulate","diffusion","performed","correspond","combinatorial","tractographies","structures","segmentation","preliminary","annealing","resulting","transformation","necessary","registration","implemented","anatomical","streamline","differences","resonance","similarities","competitive","unsupervised","backpropagation","reconstruct","auxiliary","regularization","transformer","truncated","fundamental","challenge","including","dependencies","comparable","sequences","highlight","improving","beneficial","recurrent","efficiency","substantially","parkinsons","identification","important","discriminate","initiative","established","clinically","technique","discriminatory","degeneration","prognosis","dopaminergic","clinicians","extracting","involv ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	transposable
# 	repulsion
# 	eigendecomposition
# 	tractography
# 	tractographies
# 	streamline
# 	robustifying
# 	factorize
# 	inferential
# 	contractive
# 	macroeconomic
# 	bernsteins
# 	internally
# 	sociology
# 	multitype
# 	econometrics
# 	ultrametric
# 	maximising
# 	wirtinger
# 	mcallester
# Some words which never appear in Statistics papers:
# 	transformer
# 	proactive
# 	residential
# 	casualties
# 	occlusions
# 	morphable
# 	reviewers
# 	opinionated
# 	readability
# 	alphabets
# 	countable
# 	homography
# 	milliseconds
# 	possibilistic
# 	backtrack
# 	formalisms
# 	dempsters
# 	compatibility
# 	evidential
# 	deliberately

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.063631628932937e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
